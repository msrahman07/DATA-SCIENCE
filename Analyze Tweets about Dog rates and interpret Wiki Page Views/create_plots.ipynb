# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
#filename1 = sys.argv[1]
#filename2 = sys.argv[2]
filename1 = 'pagecounts-20190509-120000.txt'
filename2 = 'pagecounts-20190509-130000.txt'

# %%
print(filename1)
# Out:
# pagecounts-20190509-120000.txt

# %%
data1 = pd.read_csv(filename1, sep=' ', header=None, index_col=1, names=['lang', 'page', 'views', 'bytes'])
data2 = pd.read_csv(filename2, sep=' ', header=None, index_col=1, names=['lang', 'page', 'views', 'bytes'])

# %%
series1 = data1['views']

series2 = data2['views']

newdf = pd.DataFrame(dict(views1 = series1, views2 = series2))
newdf
# Out:
#                                               views1  views2
# $1000                                              4     NaN
# 12_Love_Stories                                    1     NaN
# 1306                                               1     NaN
# 14th_New_York_State_Legislature                    1     NaN
# 1571                                               1     NaN
# 1902_in_Belgium                                    1     NaN
# 1949_Grand_Prix_motorcycle_racing_season           1     2.0
# 1951_in_Brazil                                     1     1.0
# 1962_Los_Angeles_State_Diablos_football_team       1     NaN
# 1969_Meistaradeildin                               1     NaN
# 1970_Baseball_Hall_of_Fame_balloting               1     NaN
# 1975_World_Women's_Handball_Championship           1     NaN
# 1976_Japanese_Grand_Prix                           1     1.0
# 1980_Campeonato_Brasileiro_Série_A                 1     1.0
# 1980_NBA_Finals                                    1     4.0
# 1983_Omloop_Het_Volk                               1     NaN
# 1986_in_Turkey                                     1     1.0
# 1990_East_German_general_election                  3     1.0
# 1995_French_Grand_Prix                             1     2.0
# 1996–97_South_Midlands_League                      1     NaN
# 1997–98_Boston_Celtics_season                      1     1.0
# 1_(number)                                         1     5.0
# 2002_(band)                                        1     NaN
# 2004_Brandenburg_state_election                    1     NaN
# 2005_Ethiopian_general_election_violence           1     NaN
# 2005_German_Grand_Prix                             1     NaN
# 2006-07_Biathlon_World_Cup                         1     NaN
# 2008_São_Paulo_F.C._season                         1     NaN
# 2010_Houston_Texans_season                         1     NaN
# 2010_Quebec_earthquake                             1     NaN
# ...                                              ...     ...
# World_of_Warcraft:_Cataclysm                       5     3.0
# X-47B                                              1     NaN
# XAVC                                               3     5.0
# XAudio2                                            1     NaN
# XHYJ-FM                                            1     NaN
# Xenia_Goodwin                                      1     2.0
# Xinjiang_Uyghur_Autonomous_Region                  2     3.0
# Xplico                                             1     NaN
# XrossMediaBar                                      2     1.0
# Yacuma                                             1     NaN
# Yasmine_Hamdan                                     4     2.0
# Yi_Dexin                                           1     NaN
# Yodwicha_Por_Boonsit                               1     NaN
# Yok-Utian_languages                                1     NaN
# Yolonda_Ross                                       3     2.0
# YouPorn                                            9    11.0
# Your_Face                                          2     NaN
# Youth_Over_Flowers                                 6     4.0
# ZF_8HP_transmission                               17    29.0
# Zain_ud-Din_Ahmed_Khan                             1     NaN
# Zebrawood                                          5     2.0
# Zim_Zum                                            1     3.0
# Zingiber_zerumbet                                  1     2.0
# Zodiac_(film)                                     43    52.0
# Zygomaticofacial_nerve                             1     1.0
# sputtering                                         7     NaN
# Ásgeir_Ásgeirsson                                  1     NaN
# Évelyne_Sullerot                                   1     NaN
# Üsküdar                                            1     5.0
# Ń                                                  5     3.0
#
# [2500 rows x 2 columns]

# %%
data1_desc_views = data1.sort_values(by='views', ascending = False)
data2_desc_views = data2.sort_values(by='views', ascending = False)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title('Popularity Distribution')
plt.xlabel('Rank')
plt.ylabel('Views')
plt.plot(data1_desc_views['views'].values, 'r-' )
plt.subplot(1, 2, 2)
plt.title('Daily Correlation')
plt.xlabel('Day 1 views')
plt.ylabel('Day 2 views')
plt.plot(newdf['views1'].values, newdf['views2'].values, 'b.')
plt.xscale('log')
plt.yscale('log')
plt.savefig('wikipedia.png')
